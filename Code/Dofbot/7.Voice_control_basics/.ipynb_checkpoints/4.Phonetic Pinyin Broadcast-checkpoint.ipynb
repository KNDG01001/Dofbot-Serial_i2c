# %%
#!/usr/bin/env python3
#coding=utf-8
import time
from Arm_Lib import Arm_Device

# 获取机械臂的对象
Arm = Arm_Device()
time.sleep(.1)

# %% [markdown]
# # 配置参数并播放：你好亚博智能科技

# %%
Arm.Arm_ask_speech(4)
time.sleep(.01)

# %% [markdown]
# # 配置参数并播放：欢迎使用亚博智能语音播报模块

# %%
Arm.Arm_ask_speech(5)
time.sleep(.01)

# %%
del Arm  # 释放掉Arm对象
