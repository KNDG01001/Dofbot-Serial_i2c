# %% [markdown]
# # 定义模块的设备地址和寄存器地址

# %%
#!/usr/bin/env python3
#coding=utf-8
import time
from Arm_Lib import Arm_Device

# 获取机械臂的对象
Arm = Arm_Device()
time.sleep(.1)

# %% [markdown]
# # 配置参数并播放：hello yahboom intelligent Technology

# %%
Arm.Arm_ask_speech(2)
time.sleep(.1)

# %% [markdown]
# # 配置参数并播放：Welcome to use yahboom intelligent technology voice broadcast module

# %%
Arm.Arm_ask_speech(3)
time.sleep(.1)

# %%
del Arm  # 释放掉Arm对象
