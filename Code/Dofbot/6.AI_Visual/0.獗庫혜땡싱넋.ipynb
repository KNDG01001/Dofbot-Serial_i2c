# %% [markdown]
# <center><img src="./logo.png" alt="Header" style="width: 800px;"/></center>

# %%
import cv2
import ipywidgets.widgets as widgets
import threading
import time

image_widget = widgets.Image(format='jpeg', width=600, height=500)  #设置摄像头显示组件
display(image_widget)                                               #显示摄像头组件
# Out:
# Image(value=b'', format='jpeg', height='500', width='600')

# %%
#bgr8转jpeg格式
import enum
import cv2

def bgr8_to_jpeg(value, quality=75):
    return bytes(cv2.imencode('.jpg', value)[1])

# %%
image = cv2.VideoCapture(0,cv2.CAP_V4L2)                           #打开摄像头

width=600
height=500
# cap.set(cv2.CAP_PROP_FRAME_WIDTH,width)#设置图像宽度
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT,height)#设置图像高度

# image.set(3,600)       
# image.set(4,500)
# image.set(5, 30)  #设置帧率
# image.set(cv2.CAP_PROP_FOURCC, cv2.VideoWriter.fourcc('M', 'J', 'P', 'G'))
# image.set(cv2.CAP_PROP_BRIGHTNESS, 40) #设置亮度 -64 - 64  0.0
# image.set(cv2.CAP_PROP_CONTRAST, 50)   #设置对比度 -64 - 64  2.0
# image.set(cv2.CAP_PROP_EXPOSURE, 156)  #设置曝光值 1.0 - 5000  156.0

ret, frame = image.read()     #读取摄像头数据
image_widget.value = bgr8_to_jpeg(frame)
# Out:
# [ WARN:0@204.719] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ WARN:0@204.719] global cap.cpp:342 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 17
#       5 # cap.set(cv2.CAP_PROP_FRAME_WIDTH,width)#设置图像宽度
#       6 # cap.set(cv2.CAP_PROP_FRAME_HEIGHT,height)#设置图像高度
#       7
#    (...)
#      13 # image.set(cv2.CAP_PROP_CONTRAST, 50)   #设置对比度 -64 - 64  2.0
#      14 # image.set(cv2.CAP_PROP_EXPOSURE, 156)  #设置曝光值 1.0 - 5000  156.0
#      16 ret, frame = image.read()     #读取摄像头数据
# ---> 17 image_widget.value = bgr8_to_jpeg(frame)
#
# Cell In[6], line 6, in bgr8_to_jpeg(value, quality)
#       5 def bgr8_to_jpeg(value, quality=75):
# ----> 6     return bytes(cv2.imencode('.jpg', value)[1])
#
# error: OpenCV(4.8.1) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1113: error: (-215:Assertion failed) !image.empty() in function 'imencode'

# %%
try:
    while 1:
        ret, frame = image.read()
        image_widget.value = bgr8_to_jpeg(frame)
        time.sleep(0.010)
except KeyboardInterrupt:
    print(" Program closed! ")
    pass

# %%
image.release()              #使用完成对象记住释放掉对象，不然下一个程序使用这个对象模块会被占用，导致无法使用
